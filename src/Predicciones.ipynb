# %% [markdown]
# # Predictions with outsiders

# %%
import predictions as predicciones

# %% [markdown]
# ## Hits

# %%
pred = predicciones.prediction_pose('../real_pics/garundanasa_2.png')
# Out:
# OUTSIDER
#
# Probabilidades totales -> ardha matsyendrasana:0.00007 bakasana:0.00004 bitilasana:0.00000 chaturanga dandasana:0.00000 garudasana:0.99968 vriksasana:0.00021

# %%
pred = predicciones.prediction_pose('../real_pics/bakasana.png')
# Out:
# OUTSIDER
#
# Probabilidades totales -> ardha matsyendrasana:0.00000 bakasana:0.99999 bitilasana:0.00000 chaturanga dandasana:0.00000 garudasana:0.00000 vriksasana:0.00000

# %%
pred = predicciones.prediction_pose('../real_pics/ardha_matsyendrasana.png')
# Out:
# OUTSIDER
#
# Probabilidades totales -> ardha matsyendrasana:0.99998 bakasana:0.00000 bitilasana:0.00000 chaturanga dandasana:0.00000 garudasana:0.00000 vriksasana:0.00002

# %%
pred = predicciones.prediction_pose('../real_pics/bitilasana.png')
# Out:
# OUTSIDER
#
# Probabilidades totales -> ardha matsyendrasana:0.00000 bakasana:0.00000 bitilasana:1.00000 chaturanga dandasana:0.00000 garudasana:0.00000 vriksasana:0.00000

# %%
pred = predicciones.prediction_pose('../real_pics/chaturanga dandanasa.png')
# Out:
# OUTSIDER
#
# Probabilidades totales -> ardha matsyendrasana:0.00000 bakasana:0.00000 bitilasana:0.00000 chaturanga dandasana:0.99977 garudasana:0.00000 vriksasana:0.00023

# %%
pred = predicciones.prediction_pose('../real_pics/vriksasana.png')
# Out:
# OUTSIDER
#
# Probabilidades totales -> ardha matsyendrasana:0.00000 bakasana:0.00000 bitilasana:0.00000 chaturanga dandasana:0.00000 garudasana:0.00099 vriksasana:0.99900

# %%
pred = predicciones.prediction_pose('../real_pics/garundanasa_3.png')
# Out:
# OUTSIDER
#
# Probabilidades totales -> ardha matsyendrasana:0.00050 bakasana:0.00016 bitilasana:0.00000 chaturanga dandasana:0.00002 garudasana:0.99747 vriksasana:0.00185

# %%
pred = predicciones.prediction_pose('../real_pics/garundanasa_4.png')
# Out:
# OUTSIDER
#
# Probabilidades totales -> ardha matsyendrasana:0.00014 bakasana:0.00000 bitilasana:0.00000 chaturanga dandasana:0.00000 garudasana:0.99986 vriksasana:0.00000

# %% [markdown]
# ## Mistakes

# %%
pred = predicciones.prediction_pose('../real_pics/garudanasa.png')
# Out:
# OUTSIDER
#
# Probabilidades totales -> ardha matsyendrasana:0.62519 bakasana:0.04232 bitilasana:0.01272 chaturanga dandasana:0.02618 garudasana:0.15838 vriksasana:0.13521
